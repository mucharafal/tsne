# %%
from sklearn.manifold import TSNE

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("test.csv")

# %%
df.values
# Out:
# array([[0.9390151 , 0.44698664, 0.83175311],
#        [0.96818936, 0.22343629, 0.27604835]])

# %%
TSNE(n_components=2).fit_transform(df.values)
# Out:
# array([[   85.52748, -1374.857  ],
#        [  -85.52754,  1374.857  ]], dtype=float32)

# %%
a = pd.read_csv("mnist_test.csv")

# %%
a.iloc[:200, 1:].to_csv("processed_mnist.csv", header=False, sep=',', index=False)

# %%
b =  pd.read_csv("out.csv", sep=" ", header= None).iloc[:, :2]

# %%
b.plot.scatter(x=0, y=1)

# %%
b.plot.scatter(x=0, y=1)

# %%
b.plot.scatter(x=0, y=1, labels=a.iloc[:200, 0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-205f5e9afbf3> in <module>
# ----> 1 b.plot.scatter(x=0, y=1, labels=a.iloc[:200, 0])
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3514             ...                       colormap='viridis')
#    3515         """
# -> 3516         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3517
#    3518     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
c = b.join(a.iloc[:200, 0])

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')

# %%
k = TSNE(n_components=2).fit_transform(a.iloc[:200, 1:].values)

# %%
b = pd.DataFrame(k)

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')

# %%
c.plot.scatter(x=0, y=1, c="label", colormap='viridis')
